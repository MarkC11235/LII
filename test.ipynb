# %%
import dis

# %%
def add(x, y):
    res = x + y
    return res

dis.dis(add)
# Out:
#   1           0 RESUME                   0
#
#   2           2 LOAD_FAST                0 (x)
#               4 LOAD_FAST                1 (y)
#               6 BINARY_OP                0 (+)
#              10 STORE_FAST               2 (res)
#
#   3          12 LOAD_FAST                2 (res)
#              14 RETURN_VALUE

# %%
def loop():
    for i in range(10):
        print(i)
        
dis.dis(loop)
# Out:
#   1           0 RESUME                   0
#
#   2           2 LOAD_GLOBAL              1 (NULL + range)
#              12 LOAD_CONST               1 (10)
#              14 CALL                     1
#              22 GET_ITER
#         >>   24 FOR_ITER                13 (to 54)
#              28 STORE_FAST               0 (i)
#
#   3          30 LOAD_GLOBAL              3 (NULL + print)
#              40 LOAD_FAST                0 (i)
#              42 CALL                     1
#              50 POP_TOP
#              52 JUMP_BACKWARD           15 (to 24)
#
#   2     >>   54 END_FOR
#              56 RETURN_CONST             0 (None)

# %%
def if_stmt(x):
    if x > 0:
        return x
    else:
        return -x
    
dis.dis(if_stmt)
# Out:
#   1           0 RESUME                   0
#
#   2           2 LOAD_FAST                0 (x)
#               4 LOAD_CONST               1 (0)
#               6 COMPARE_OP              68 (>)
#              10 POP_JUMP_IF_FALSE        2 (to 16)
#
#   3          12 LOAD_FAST                0 (x)
#              14 RETURN_VALUE
#
#   5     >>   16 LOAD_FAST                0 (x)
#              18 UNARY_NEGATIVE
#              20 RETURN_VALUE

# %%
def expr_stmt(x):
    y = x**2 + 2*x + 1
    return y

dis.dis(expr_stmt)
# Out:
#   1           0 RESUME                   0
#
#   2           2 LOAD_FAST                0 (x)
#               4 LOAD_CONST               1 (2)
#               6 BINARY_OP                8 (**)
#              10 LOAD_CONST               1 (2)
#              12 LOAD_FAST                0 (x)
#              14 BINARY_OP                5 (*)
#              18 BINARY_OP                0 (+)
#              22 LOAD_CONST               2 (1)
#              24 BINARY_OP                0 (+)
#              28 STORE_FAST               1 (y)
#
#   3          30 LOAD_FAST                1 (y)
#              32 RETURN_VALUE

# %%
import time
import random

# %%
start = time.time()
# bubble sort
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
    return arr

size = 100
# random array of integers between 0 and 1000
arr = [random.randint(0, 1000) for _ in range(size)]
print(arr)
print(bubble_sort(arr))
print("Time taken: ", time.time() - start)
# Out:
# [729, 647, 64, 228, 248, 921, 640, 871, 18, 66, 703, 79, 251, 743, 547, 223, 385, 386, 450, 685, 210, 850, 434, 907, 932, 918, 777, 473, 380, 482, 447, 489, 791, 752, 550, 895, 943, 898, 676, 76, 462, 808, 272, 730, 9, 888, 727, 603, 181, 502, 715, 53, 433, 286, 949, 850, 151, 667, 865, 708, 679, 62, 54, 600, 438, 695, 667, 857, 670, 292, 275, 927, 647, 306, 261, 274, 403, 96, 92, 738, 83, 287, 783, 963, 54, 848, 338, 575, 497, 74, 832, 670, 954, 781, 4, 718, 361, 329, 750, 799]
# [4, 9, 18, 53, 54, 54, 62, 64, 66, 74, 76, 79, 83, 92, 96, 151, 181, 210, 223, 228, 248, 251, 261, 272, 274, 275, 286, 287, 292, 306, 329, 338, 361, 380, 385, 386, 403, 433, 434, 438, 447, 450, 462, 473, 482, 489, 497, 502, 547, 550, 575, 600, 603, 640, 647, 647, 667, 667, 670, 670, 676, 679, 685, 695, 703, 708, 715, 718, 727, 729, 730, 738, 743, 750, 752, 777, 781, 783, 791, 799, 808, 832, 848, 850, 850, 857, 865, 871, 888, 895, 898, 907, 918, 921, 927, 932, 943, 949, 954, 963]
# ...

# %%
2 * [2 * [0]]
# Out:
# [[0, 0], [0, 0]]

# %%
import sys

def convert_ttf_to_cpp(ttf_path, output_path):
    with open(ttf_path, 'rb') as f:
        font_data = f.read()
    
    with open(output_path, 'w') as f:
        f.write('// Auto-generated file from ttf_to_cpp.py\n')
        f.write('#include "embedded_font.hpp"\n\n')
        f.write('const unsigned char embedded_font[] = {')
        
        for i, byte in enumerate(font_data):
            if i % 12 == 0:
                f.write('\n    ')
            f.write(f'0x{byte:02x}, ')
        
        f.write('\n};\n\n')
        f.write(f'const unsigned int embedded_font_size = {len(font_data)};\n')

if __name__ == '__main__':
    if len(sys.argv) != 3:
        print('Usage: python ttf_to_cpp.py input.ttf output.cpp')
        sys.exit(1)
    
    convert_ttf_to_cpp(sys.argv[1], sys.argv[2])

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data points: logarithm of step size vs. logarithm of error
x_values = [-2.3025850929940455, -4.605170185988091, -6.907755278982137, -9.210340371976182]
y_values = [-3.0638686374026607, -5.427322550059435, -7.7358678185709415, -10.039047671285527]

# Create the plot
plt.figure(figsize=(10, 6))
plt.scatter(x_values, y_values, color='blue', s=60, label='Data points')

# Add best fit line
slope, intercept = np.polyfit(x_values, y_values, 1)
fit_x = np.array([min(x_values), max(x_values)])
fit_y = slope * fit_x + intercept
plt.plot(fit_x, fit_y, color='red', linestyle='--', 
         label=f'Best fit: y = {slope:.2f}x + {intercept:.2f}')

# Add labels and title
plt.xlabel('ln(step size)')
plt.ylabel('ln(error)')
plt.title('Logarithm of Error vs. Logarithm of Step Size')
plt.grid(True, alpha=0.3)
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# Print the slope for convergence rate analysis
print(f"Slope of the line: {slope:.4f}")
# Out:
# Slope of the line: 1.0090
