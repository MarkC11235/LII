# %%
import matplotlib.pyplot as plt
import numpy as np

# Example data
# x_vec = [-2.3025850929940455,
#         -4.605170185988091,
#         -6.907755278982137,
#         -9.210340371976182]
# y_vec = [-5.31889379915369,
#         -10.033233284410864,
#         -14.649585557457835,
#         -19.255881640739922]

# x_vec = [-2.3025850929940455,
#          -4.605170185988091, 
#          -6.907755278982137, 
#          -9.210340371976182]
# y_vec = [-7.60396132079613,
#          -14.667492937742557,
#          -21.591245402023997,
#          -28.43897681053056]

# x_vec = [-2.3025850929940455, 
# -4.605170185988091, 
# -6.907755278982137, 
# -9.210340371976182, ]
# y_vec = [-13.16021413812597
# , -22.5480080618747
# , -30.794329332371227
# , -31.29276079878344]

# x_vec = [-2.3025850929940455,
# -4.605170185988091,
# -6.907755278982137]
# y_vec = [ -1.3899771133846655
# , -5.8173380736229285
# , -10.403739472327784]

x_vec = [-2.3025850929940455,
-4.605170185988091,
-6.907755278982137]
y_vec = [ -8.671895649263876
, -16.065504205675442
, -16.08857394835705]


slope, intercept = np.polyfit(x_vec, y_vec, 1)

# Plotting
plt.plot(x_vec, y_vec, marker='o', linestyle='-', color='b')
plt.xlabel('ln|h|')
plt.ylabel('ln|y(2*PI)_exact - y(2*PI)_approx|')
plt.title('ln|y(2*PI)_exact - y(2*PI)_approx| vs ln|h|')
plt.text(-6.5, -12.5, f'y = {slope:.2f}x + {intercept:.2f}', fontsize=10, color='red')
plt.grid(True)
plt.show()
